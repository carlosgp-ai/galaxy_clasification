# %%
# !pip install opencv-python

# %%
import pandas as pd
import glob
import cv2 as cv
import shutil

# %%
path = glob.glob("NGC/*.jpg")
cv_img = []
name_file = []
for img in path:
    name_file.append(img)
    n = cv.imread(img)
    cv_img.append(n)

# %%
len(cv_img)
# Out:
# 383

# %%
import pandas as pd

df = pd.read_excel ('SDSS_IAC_Galaxy_Class.xlsx',  header=None)
df
# Out:
#                    0  1   2       3        4        5          6
# 0     2MASXJ09065870  E   2  11,844  -23,295  0,56205       -999
# 1        CGCG163-062  S  cd  9,6358  -19,404  0,91982    15,0518
# 2        CGCG242-073  E   3   11,64  -23,118     -999       -999
# 3        CGCG429-012  E   6  10,167  -19,968     -999       -999
# 4        CGCG536-030  S  dm  9,6528  -20,129  0,59152       -999
# ..               ... ..  ..     ...      ...      ...        ...
# 378  UGC12494NOTES01  E   2  9,8563  -19,416  0,63425       -999
# 379         UGC12810  S  bc   10,81  -21,756  0,38947   34,30494
# 380         UGC12816  S   c  9,7923  -20,404  0,50727       -999
# 381         UGC12864  S   c  10,021  -20,198  0,37445   36,30604
# 382          UGCA021  S  dm  9,1958  -18,646  0,92903  21.07252]
#
# [383 rows x 7 columns]

# %%
df.dtypes
# Out:
# 0     object
# 1     object
# 2     object
# 3    float64
# 4    float64
# 5    float64
# 6     object
# dtype: object

# %%
dfE = df[df[1] == 'E']
dfS = df[df[1] == 'S']
dfI = df[df[1] == 'I']

# %%
dfS0a = dfS[(dfS[2] == '0') | (dfS[2] == '0a')]
dfSab = dfS[(dfS[2] == 'a') | (dfS[2] == 'ab')]
dfSb = dfS[(dfS[2] == 'b')]
dfSbc = dfS[(dfS[2] == 'bc')]
dfScd = dfS[(dfS[2] == 'c') | (dfS[2] == 'cd')]
dfSdm = dfS[(dfS[2] == 'd') | (dfS[2] == 'dm') | (dfS[2] == 'm')]

# %%
len(dfSbc)
# Out:
# 78

# %%
for i in dfE.index: 
     #print(dfE[0][i]+".jpg")
    shutil.copy('C:\\Users\\cgarcia51\\NGC\\'+dfE[0][i]+'_SDSS.jpg','C:\\Users\\cgarcia51\\NGCClassification\\E\\'+dfE[0][i]+'_SDSS.jpg')

# %%
for i in dfS0a.index: 
    shutil.copy('C:\\Users\\cgarcia51\\NGC\\'+dfS0a[0][i]+'_SDSS.jpg','C:\\Users\\cgarcia51\\NGCClassification\\S0a\\'+dfS0a[0][i]+'_SDSS.jpg')

# %%
for i in dfSab.index: 
    shutil.copy('C:\\Users\\cgarcia51\\NGC\\'+dfSab[0][i]+'_SDSS.jpg','C:\\Users\\cgarcia51\\NGCClassification\\Sab\\'+dfSab[0][i]+'_SDSS.jpg')
for i in dfSb.index: 
    shutil.copy('C:\\Users\\cgarcia51\\NGC\\'+dfSb[0][i]+'_SDSS.jpg','C:\\Users\\cgarcia51\\NGCClassification\\Sb\\'+dfSb[0][i]+'_SDSS.jpg')
for i in dfSbc.index: 
    shutil.copy('C:\\Users\\cgarcia51\\NGC\\'+dfSbc[0][i]+'_SDSS.jpg','C:\\Users\\cgarcia51\\NGCClassification\\Sbc\\'+dfSbc[0][i]+'_SDSS.jpg')
for i in dfScd.index: 
    shutil.copy('C:\\Users\\cgarcia51\\NGC\\'+dfScd[0][i]+'_SDSS.jpg','C:\\Users\\cgarcia51\\NGCClassification\\Scd\\'+dfScd[0][i]+'_SDSS.jpg')
for i in dfSdm.index: 
    shutil.copy('C:\\Users\\cgarcia51\\NGC\\'+dfSdm[0][i]+'_SDSS.jpg','C:\\Users\\cgarcia51\\NGCClassification\\Sdm\\'+dfSdm[0][i]+'_SDSS.jpg')
for i in dfI.index: 
    shutil.copy('C:\\Users\\cgarcia51\\NGC\\'+dfI[0][i]+'_SDSS.jpg','C:\\Users\\cgarcia51\\NGCClassification\\I\\'+dfI[0][i]+'_SDSS.jpg')

# %%
import os

# %%
os.getcwdb()
# Out:
# C:\Users\cgarcia51\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: The Windows bytes API has been deprecated, use Unicode filenames instead
#   """Entry point for launching an IPython kernel.
# b'C:\\Users\\cgarcia51'

# %%
os.listdir("C:\\Users\\cgarcia51\\NGC\\")
# Out:
# ['2MASXJ09065870_SDSS.jpg',
#  'CGCG163-062_SDSS.jpg',
#  'CGCG242-073_SDSS.jpg',
#  'CGCG429-012_SDSS.jpg',
#  'CGCG536-030_SDSS.jpg',
#  'ESO540-G003_SDSS.jpg',
#  'IC0159_SDSS.jpg',
#  'IC0208_SDSS.jpg',
#  'IC0307_SDSS.jpg',
#  'IC0674_SDSS.jpg',
#  'IC0776_SDSS.jpg',
#  'IC0944_SDSS.jpg',
#  'IC0994_SDSS.jpg',
#  'IC1078_SDSS.jpg',
#  'IC1151_SDSS.jpg',
#  'IC1199_SDSS.jpg',
#  'IC1256_SDSS.jpg',
#  'IC1528_SDSS.jpg',
#  'IC1602_SDSS.jpg',
#  'IC1683_SDSS.jpg',
#  'IC2341_SDSS.jpg',
#  'IC2378_SDSS.jpg',
#  'IC2402_SDSS.jpg',
#  'IC2481_SDSS.jpg',
#  'IC2604_SDSS.jpg',
#  'IC3065_SDSS.jpg',
#  'IC3586_SDSS.jpg',
#  'IC3652_SDSS.jpg',
#  'IC3918_SDSS.jpg',
#  'IC4534_SDSS.jpg',
#  'IC4566_SDSS.jpg',
#  'IC5309_SDSS.jpg',
#  'KUG0210-078_SDSS.jpg',
#  'KUG1349+143_SDSS.jpg',
#  'LSBCF560-04_SDSS.jpg',
#  'MCG+07-17-002_SDSS.jpg',
#  'MCG+09-18-064_SDSS.jpg',
#  'MCG+10-17-007_SDSS.jpg',
#  'MCG-01-09-006_SDSS.jpg',
#  'MCG-01-10-015_SDSS.jpg',
#  'MCG-01-10-019_SDSS.jpg',
# ...
